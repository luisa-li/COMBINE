# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
rms = pd.read_csv("02_03.rms", sep="       ")
rms.reset_index(inplace=True)
rms.columns = ["Frame", "RMSD"]
rms
# Out:
# /var/folders/f1/1727nmns4pn3qwy09yz08x2r0000gn/T/ipykernel_45057/2033769277.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   rms = pd.read_csv("02_03.rms", sep="       ")
#         Frame    RMSD
# 0           2  0.0883
# 1           4  0.1168
# 2           6  0.0812
# 3           8  0.0950
# 4          10  0.0664
# ...       ...     ...
# 50095  100192  0.5376
# 50096  100194  0.4713
# 50097  100196  0.5238
# 50098  100198  0.6056
# 50099  100200  0.5116
#
# [50100 rows x 2 columns]

# %%
plt.figure(figsize=(20, 10))  # Width x Height in inches
sns.lineplot(x="Frame", y="RMSD", data=rms, linewidth=0.5)
# Out:
# <Axes: xlabel='Frame', ylabel='RMSD'>
